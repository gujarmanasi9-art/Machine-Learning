# %%
#importing essential libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from matplotlib import rcParams as rcP
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\inter\Desktop\Mansi\Pune house\Pune_rent.csv')
df.head()
# Out:
#   seller_type  bedroom layout_type      property_type  locality   price  area  \
# 0       OWNER        1         BHK  Independent Floor   Mundhwa   6,750   450
# 1       OWNER        2         BHK          Apartment     Wakad  18,000   916
# 2       OWNER        3         BHK          Apartment   Wagholi  16,500  1085
# 3       OWNER        1          RK   Studio Apartment   Kothrud   8,000   250
# 4       OWNER        2         BHK          Apartment  Yerawada  25,000  1005
#
#      furnish_type bathroom
# 0     Unfurnished        1
# 1     Unfurnished        2
# 2  Semi-Furnished        3
# 3       Furnished        1
# 4  Semi-Furnished        2

# %%
df.shape
# Out:
# (22800, 9)

# %%
df.describe().transpose()
# Out:
#            count         mean         std    min    25%    50%     75%     max
# bedroom  22800.0     1.873465    0.793189    1.0    1.0    2.0     2.0     8.0
# area     22800.0  1041.622588  588.915990  100.0  650.0  960.0  1200.0  7500.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22800 entries, 0 to 22799
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   seller_type    22800 non-null  object
#  1   bedroom        22800 non-null  int64
#  2   layout_type    22800 non-null  object
#  3   property_type  22800 non-null  object
#  4   locality       22800 non-null  object
#  5   price          22800 non-null  object
#  6   area           22800 non-null  int64
#  7   furnish_type   22800 non-null  object
#  8   bathroom       22629 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# seller_type        0
# bedroom            0
# layout_type        0
# property_type      0
# locality           0
# price              0
# area               0
# furnish_type       0
# bathroom         171
# dtype: int64

# %%
# Use the actual column name from this dataset
# Available columns: seller_type, bedroom, layout_type, property_type, locality, price, area, furnish_type, bathroom

# Count entries by layout type

df.groupby('layout_type')['layout_type'].count()
# Out:
# layout_type
# BHK    21726
# RK      1074
# Name: layout_type, dtype: int64

# %%
df.groupby('availability')['availability'].agg('count')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.groupby('availability')['availability'].agg('count')
#
# File c:\Users\inter\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...
